# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("running python from", sys.executable)

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 10, 50); y = 3*x + 4

# %%
plt.scatter(x, y, s=10); plt.plot(x, 3*x+4)
